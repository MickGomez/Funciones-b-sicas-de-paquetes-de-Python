# %% [markdown]
# # Titulo

# %% [markdown]
# ## subtitulo

# %% [markdown]
# escribiendo algo de prueba

# %%
1+1
# Out:
# 2

# %% [markdown]
# # Imprimir código

# %%
x = 'nombre'

# %%
print(x)
# Out:
# nombre

# %% [markdown]
# # tabla

# %%
import pandas as pd

tabla=pd.DataFrame(data = [ [1,1],[2,4],[4,16],[6,36],[8,64]],
                   columns = ['numero','cuadrado'])
tabla
# Out:
#    numero  cuadrado
# 0       1         1
# 1       2         4
# 2       4        16
# 3       6        36
# 4       8        64

# %% [markdown]
# # Gráfica

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [1,23,45,67,89]

plt.plot(x,y)
plt.show()

# %% [markdown]
# # Imagen

# %% [markdown]
# ![pernoM2.jpg](attachment:00e41145-5437-4784-aeb8-78c99b6f2bb2.jpg)

# %% [markdown]
# # Conclusiones
# * Primera
# * Segunda
# * Tercera
